# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data = "https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv"

# %%
if not os.path.isfile("data.csv"):
    # !wget $data

# %%
# !ls
# Out:
# car_price_prediction_regression.ipynb  data.csv.1  data.csv.3  Untitled.ipynb
# data.csv			       data.csv.2  data.csv.4

# %%
# load data and preview
df = pd.read_csv("data.csv")
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
# make column consisted lower and underscores
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
# the string columns are not consistent.
# find all string columns 

str_columns = df.dtypes[df.dtypes == 'object'].index 
for col in str_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  factory_tuner,luxury,high-performance      compact         coupe
# 1                     luxury,performance      compact   convertible
# 2                luxury,high-performance      compact         coupe
# 3                     luxury,performance      compact         coupe
# 4                                 luxury      compact   convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %% [markdown]
# ## EDA

# %%
# lets check for kinds of values in each columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11911 non-null  object
#  4   engine_hp          11845 non-null  float64
#  5   engine_cylinders   11884 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11908 non-null  float64
#  9   market_category    8172 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#                year    engine_hp  engine_cylinders  number_of_doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway_mpg      city_mpg    popularity          msrp
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.100000e+04
# 50%       26.000000     18.000000   1385.000000  2.999500e+04
# 75%       30.000000     22.000000   2009.000000  4.223125e+04
# max      354.000000    137.000000   5657.000000  2.065902e+06

# %%
for col in df.columns:
    print(col)
    print("Nunique: ", df[col].nunique())
    print("Some Unique values: ", df[col].unique()[:5])
    print("Missing count: ", df[col].isnull().sum())
    print("---" * 30)
# Out:
# make
# Nunique:  48
# Some Unique values:  ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler']
# Missing count:  0
# ------------------------------------------------------------------------------------------
# model
# Nunique:  914
# Some Unique values:  ['1_series_m' '1_series' '100' '124_spider' '190-class']
# Missing count:  0
# ------------------------------------------------------------------------------------------
# year
# Nunique:  28
# Some Unique values:  [2011 2012 2013 1992 1993]
# Missing count:  0
# ------------------------------------------------------------------------------------------
# engine_fuel_type
# Nunique:  10
# Some Unique values:  ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel']
# Missing count:  3
# ------------------------------------------------------------------------------------------
# engine_hp
# Nunique:  356
# Some Unique values:  [335. 300. 230. 320. 172.]
# Missing count:  69
# ------------------------------------------------------------------------------------------
# engine_cylinders
# Nunique:  9
# Some Unique values:  [ 6.  4.  5.  8. 12.]
# Missing count:  30
# ------------------------------------------------------------------------------------------
# transmission_type
# Nunique:  5
# Some Unique values:  ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
# Missing count:  0
# ------------------------------------------------------------------------------------------
# driven_wheels
# Nunique:  4
# Some Unique values:  ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
# Missing count:  0
# ------------------------------------------------------------------------------------------
# number_of_doors
# Nunique:  3
# Some Unique values:  [ 2.  4.  3. nan]
# Missing count:  6
# ------------------------------------------------------------------------------------------
# market_category
# Nunique:  71
# Some Unique values:  ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance']
# Missing count:  3742
# ------------------------------------------------------------------------------------------
# vehicle_size
# Nunique:  3
# Some Unique values:  ['compact' 'midsize' 'large']
# Missing count:  0
# ------------------------------------------------------------------------------------------
# vehicle_style
# Nunique:  16
# Some Unique values:  ['coupe' 'convertible' 'sedan' 'wagon' '4dr_hatchback']
# Missing count:  0
# ------------------------------------------------------------------------------------------
# highway_mpg
# Nunique:  59
# Some Unique values:  [26 28 27 25 24]
# Missing count:  0
# ------------------------------------------------------------------------------------------
# city_mpg
# Nunique:  69
# Some Unique values:  [19 20 18 17 16]
# Missing count:  0
# ------------------------------------------------------------------------------------------
# popularity
# Nunique:  48
# Some Unique values:  [3916 3105  819  617 1013]
# Missing count:  0
# ------------------------------------------------------------------------------------------
# msrp
# Nunique:  6049
# Some Unique values:  [46135 40650 36350 29450 34500]
# Missing count:  0
# ------------------------------------------------------------------------------------------

# %%
# price distribution
fig, (ax1, ax2) = plt.subplots(2,1)
sns.histplot(df.msrp, bins=100, ax=ax1)
sns.histplot(df[df.msrp < 100000].msrp, bins=100, ax=ax2)
# Out:
# <AxesSubplot:xlabel='msrp', ylabel='Count'>

# %%
# log of price distribution
sns.histplot(np.log1p(df.msrp), bins=100);

# %% [markdown]
# ## Testing, Validation and Training Dataset

# %%
# feature egineering
df["age"] = df.year.max() -df.year
df.age.unique()
# Out:
# array([ 6,  5,  4, 25, 24, 23,  0, 26,  1, 27,  2, 21, 20, 19,  3, 18, 15,
#        14, 13, 22, 10,  9,  8, 16,  7, 17, 12, 11])

# %%
# randomize dataset
idx = np.arange(df.shape[0]) #create list of 0 - n-1

np.random.seed(2) # to always get same randomness
np.random.shuffle(idx) # shuffle list


df = df.iloc[idx]
df.reset_index(drop=True, inplace=True)

# %%
# take log to normalize target variable
df["msrp"] = np.log1p(df["msrp"])

# %%
df.head()
# Out:
#          make    model  year          engine_fuel_type  engine_hp  \
# 0   chevrolet   cobalt  2008          regular_unleaded      148.0
# 1      toyota   matrix  2012          regular_unleaded      132.0
# 2      subaru  impreza  2016          regular_unleaded      148.0
# 3  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4        ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#    engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0               4.0            manual  front_wheel_drive              2.0
# 1               4.0         automatic  front_wheel_drive              4.0
# 2               4.0         automatic    all_wheel_drive              4.0
# 3               4.0            manual   rear_wheel_drive              3.0
# 4               8.0         automatic   four_wheel_drive              4.0
#
#   market_category vehicle_size      vehicle_style  highway_mpg  city_mpg  \
# 0             NaN      compact              coupe           33        24
# 1       hatchback      compact      4dr_hatchback           32        25
# 2       hatchback      compact      4dr_hatchback           37        28
# 3             NaN        large  passenger_minivan           18        16
# 4       flex_fuel        large    crew_cab_pickup           21        15
#
#    popularity       msrp  age
# 0        1385   9.575747    9
# 1        2031   9.887663    5
# 2         640   9.893235    1
# 3         873   7.601402   26
# 4        5657  10.937757    0

# %%
df_copy = df.copy()
special_cols = []
categories = ['make', 'engine_fuel_type', 'transmission_type', 'driven_wheels']
for category in categories:
    top_ten_val = df_copy[category].value_counts().index[:5]
    for val in top_ten_val:
        df_copy["%s_%s" % (category, val)] = (df_copy[category] == val).astype('int')
        special_cols.append("%s_%s" % (category, val))

# %%
df = df_copy

# %%
#data sizes
test_size = int(df.shape[0] * 0.2)
val_size = int(df.shape[0] * 0.2)
train_size = df.shape[0] - test_size - val_size

# test_data
X_test = df[:test_size]

#val_data
X_val = df[test_size:test_size+train_size]

#training_data
X_train = df[test_size+train_size:]

# confirmation
print(df.shape, (X_test.shape[0] + X_val.shape[0] + X_train.shape[0]))
# Out:
# (11914, 46) 11914

# %%
cols = ['engine_hp','engine_cylinders','highway_mpg', 'city_mpg', 'popularity', 'age'] + special_cols

# %%
X_train
# Out:
#                 make           model  year          engine_fuel_type  \
# 9532             gmc         vandura  1994          regular_unleaded
# 9533   mercedes-benz       600-class  1993          regular_unleaded
# 9534          toyota           venza  2013          regular_unleaded
# 9535           volvo             740  1992          regular_unleaded
# 9536            ford  crown_victoria  2010  flex-fuel_(unleaded/e85)
# ...              ...             ...   ...                       ...
# 11909      chevrolet       chevy_van  1998          regular_unleaded
# 11910         subaru    xv_crosstrek  2014          regular_unleaded
# 11911          dodge          magnum  2006          regular_unleaded
# 11912          honda           civic  2016          regular_unleaded
# 11913         subaru         outback  2015          regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 9532       165.0               6.0         automatic   rear_wheel_drive
# 9533       389.0              12.0         automatic   rear_wheel_drive
# 9534       268.0               6.0         automatic    all_wheel_drive
# 9535       114.0               4.0         automatic   rear_wheel_drive
# 9536       224.0               8.0         automatic   rear_wheel_drive
# ...          ...               ...               ...                ...
# 11909      200.0               6.0         automatic   rear_wheel_drive
# 11910      160.0               4.0         automatic    all_wheel_drive
# 11911      250.0               6.0         automatic    all_wheel_drive
# 11912      174.0               4.0         automatic  front_wheel_drive
# 11913      256.0               6.0         automatic    all_wheel_drive
#
#        number_of_doors        market_category  ...  \
# 9532               3.0                    NaN  ...
# 9533               2.0                 luxury  ...
# 9534               4.0  crossover,performance  ...
# 9535               4.0                 luxury  ...
# 9536               4.0              flex_fuel  ...
# ...                ...                    ...  ...
# 11909              3.0                    NaN  ...
# 11910              4.0       crossover,hybrid  ...
# 11911              4.0                    NaN  ...
# 11912              4.0                    NaN  ...
# 11913              4.0              crossover  ...
#
#       engine_fuel_type_natural_gas transmission_type_automatic  \
# 9532                             0                           1
# 9533                             0                           1
# 9534                             0                           1
# 9535                             0                           1
# 9536                             0                           1
# ...                            ...                         ...
# 11909                            0                           1
# 11910                            0                           1
# 11911                            0                           1
# 11912                            0                           1
# 11913                            0                           1
#
#        transmission_type_manual  transmission_type_automated_manual  \
# 9532                          0                                   0
# 9533                          0                                   0
# 9534                          0                                   0
# 9535                          0                                   0
# 9536                          0                                   0
# ...                         ...                                 ...
# 11909                         0                                   0
# 11910                         0                                   0
# 11911                         0                                   0
# 11912                         0                                   0
# 11913                         0                                   0
#
#        transmission_type_direct_drive  transmission_type_unknown  \
# 9532                                0                          0
# 9533                                0                          0
# 9534                                0                          0
# 9535                                0                          0
# 9536                                0                          0
# ...                               ...                        ...
# 11909                               0                          0
# 11910                               0                          0
# 11911                               0                          0
# 11912                               0                          0
# 11913                               0                          0
#
#        driven_wheels_front_wheel_drive  driven_wheels_rear_wheel_drive  \
# 9532                                 0                               1
# 9533                                 0                               1
# 9534                                 0                               0
# 9535                                 0                               1
# 9536                                 0                               1
# ...                                ...                             ...
# 11909                                0                               1
# 11910                                0                               0
# 11911                                0                               0
# 11912                                1                               0
# 11913                                0                               0
#
#        driven_wheels_all_wheel_drive  driven_wheels_four_wheel_drive
# 9532                               0                               0
# 9533                               0                               0
# 9534                               1                               0
# 9535                               0                               0
# 9536                               0                               0
# ...                              ...                             ...
# 11909                              0                               0
# 11910                              1                               0
# 11911                              1                               0
# 11912                              0                               0
# 11913                              1                               0
#
# [2382 rows x 46 columns]

# %%
# extract target variables for each
y_test = X_test.msrp
del X_test["msrp"]
print("y_test: ", y_test.values)
X_test = X_test[cols].fillna(0).values


# extract target variables for each
y_val = X_val.msrp
del X_val["msrp"]
print("y_val: ", y_val.values)
X_val = X_val[cols].fillna(0).values

# extract target variables for each
y_train = X_train.msrp
del X_train["msrp"]
print("y_train: ", y_train.values)
X_train = X_train[cols].fillna(0).values
# Out:
# y_test:  [ 9.57574708  9.887663    9.89323518 ...  9.97399261 10.92595647
#  10.13701698]
# y_val:  [ 9.85224689  9.58190393 11.62626308 ... 11.21756062  9.77542688
#  10.1924563 ]
# y_train:  [ 7.60140233  8.07464908 10.34563811 ... 10.27852782 10.00789261
#  10.40414162]

# %%
def train_linear_reg(X, y, r=0):
    ones = np.ones(X.shape[0])
    X = np.column_stack((ones, X))
    XTX = X.T.dot(X)
    
    XTX = XTX + r * np.eye(XTX.shape[0])
    
    XTX_inv = np.linalg.inv(XTX)
    weights = XTX_inv.dot(X.T).dot(y)

    return weights[0], weights[1:]

w0, w = train_linear_reg(X_train, y_train, r=0.01)

# %%
X_train.dtype
# Out:
# dtype('float64')

# %%
y_pred = w0 + X_train.dot(w)
sns.histplot(y_train, bins=70, color='red', alpha=0.5)
sns.histplot(y_pred, bins=70, color='blue', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='msrp', ylabel='Count'>

# %% [markdown]
# ## RMSE

# %%
def rmse(y, y_pred):
    se = (y-y_pred) ** 2
    return np.sqrt(se.mean())

# %%
rmse(y_train, y_pred)
# Out:
# 0.44927429224068277

# %% [markdown]
# ## Validation

# %%
y_pred = w0+X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# 0.48030770739894807
